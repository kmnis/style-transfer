# %%
# !ls  | head
# Out:
# raw_style_faces
# raw_style_faces00000_0.png
# raw_style_faces00001_0.png
# raw_style_faces00002_0.png
# raw_style_faces00003_0.png
# raw_style_faces00004_0.png
# raw_style_faces00005_0.png
# raw_style_faces00006_0.png
# raw_style_faces00007_0.png
# raw_style_faces00008_0.png
# ls: write error: Broken pipe

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread("data/face_photo/face_cartoon/raw_style_faces00006_0.png")
plt.imshow(img)
plt.show()

# %%
img = plt.imread("data/face_photo/00010.jpg")
plt.imshow(img)
plt.show()

# %%
img = plt.imread("source/stylegan2/face_generation/experiment_stylegan/ffhq_style_s256/sample/001400.png")
plt.imshow(img)
plt.show()

# %%
img = plt.imread("source/stylegan2/face_generation/experiment_stylegan/ffhq_style_s256/sample/000000.png")
plt.imshow(img)
plt.show()

# %%
img = plt.imread("data/face_cartoon/syn_style_faces/000026.png")
plt.imshow(img)
plt.show()

# %%
img = plt.imread("data/face_cartoon/total_rotate/raw_style_faces/Alicia Keys_0_0_-6.png")
plt.imshow(img)
plt.show()

# %%
img = plt.imread("data/face_cartoon/total_rotate/total_flip/syn_style_faces/000000_4.png")
plt.imshow(img)
plt.show()
